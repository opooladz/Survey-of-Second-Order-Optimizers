# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
train_loss_sgd = np.load('./loss_acc_timing/mnist_cnn_SGD_train_loss.npy')
test_acc_sgd = np.load('./loss_acc_timing/mnist_cnn_SGD_test_acc.npy')
train_loss_adam = np.load('./loss_acc_timing/mnist_cnn_Adam_train_loss.npy')
test_acc_adam = np.load('./loss_acc_timing/mnist_cnn_Adam_test_acc.npy')
train_loss_adam = np.load('./loss_acc_timing/mnist_cnn_Adam_train_loss.npy')
test_acc_adam = np.load('./loss_acc_timing/mnist_cnn_Adam_test_acc.npy')
# train_loss_lm = np.load('./loss_acc_timing/mnist_cnn_LM_train_loss.npy',allow_pickle=True)
# test_acc_lm = np.load('./loss_acc_timing/mnist_cnn_LM_test_acc.npy',allow_pickle=True)
train_loss_lm_100 = np.load('./loss_acc_timing/mnist_cnn_LM_train_loss_100.npy',allow_pickle=True)
test_acc_lm_100 = np.load('./loss_acc_timing/mnist_cnn_LM_test_acc_100.npy',allow_pickle=True)
train_loss_lm_o = np.load('./loss_acc_timing_copy/mnist_cnn_LM_train_loss.npy',allow_pickle=True)
test_acc_lm_o = np.load('./loss_acc_timing_copy/mnist_cnn_LM_test_acc.npy',allow_pickle=True)
train_loss_lbfgs = np.load('./loss_acc_timing/mnist_cnn_lbfgs_train_loss_.npy',allow_pickle=True)
test_acc_lbfgs = np.load('./loss_acc_timing/mnist_cnn_lbfgs_test_acc_.npy',allow_pickle=True)
train_loss_hf = np.load('./loss_acc_timing/mnist_cnn_HF_train_loss_.npy',allow_pickle=True)
test_acc_hf = np.load('./loss_acc_timing/mnist_cnn_HF_test_acc_.npy',allow_pickle=True)
train_loss_ekfac = np.load('./loss_acc_timing/mnist_cnn_EKFAC_train_loss.npy',allow_pickle=True)
test_acc_ekfac = np.load('./loss_acc_timing/mnist_cnn_EKFAC_test_acc.npy',allow_pickle=True)
train_loss_kfac = np.load('./loss_acc_timing/mnist_cnn_KFAC_train_loss.npy',allow_pickle=True)
test_acc_kfac = np.load('./loss_acc_timing/mnist_cnn_KFAC_test_acc.npy',allow_pickle=True)
train_loss_ekfac_adam = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_train_loss.npy',allow_pickle=True)
test_acc_ekfac_adam = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_test_acc.npy',allow_pickle=True)
train_loss_kfac_adam = np.load('./loss_acc_timing/mnist_cnn_KFAC-Adam_train_loss.npy',allow_pickle=True)
test_acc_kfac_adam = np.load('./loss_acc_timing/mnist_cnn_KFAC-Adam_test_acc.npy',allow_pickle=True)

train_loss_sgd = np.load('./loss_acc_timing/mnist_cnn_SGD_train_loss.npy')
train_acc_sgd = np.load('./loss_acc_timing/mnist_cnn_SGD_train_acc.npy')
test_loss_sgd = np.load('./loss_acc_timing/mnist_cnn_SGD_test_loss.npy')
test_acc_sgd = np.load('./loss_acc_timing/mnist_cnn_SGD_test_acc.npy')


train_loss_adam = np.load('./loss_acc_timing/mnist_cnn_Adam_train_loss.npy')
train_acc_adam = np.load('./loss_acc_timing/mnist_cnn_Adam_train_acc.npy')
test_loss_adam = np.load('./loss_acc_timing/mnist_cnn_Adam_train_loss.npy')
test_acc_adam = np.load('./loss_acc_timing/mnist_cnn_Adam_test_acc.npy')

# train_loss_lm = np.load('./loss_acc_timing/mnist_cnn_LM_train_loss.npy', allow_pickle=True)
# train_acc_lm = np.load('./loss_acc_timing/mnist_cnn_LM_train_acc.npy', allow_pickle=True)
# test_loss_lm = np.load('./loss_acc_timing/mnist_cnn_LM_test_loss.npy', allow_pickle=True) 
# test_acc_lm = np.load('./loss_acc_timing/mnist_cnn_LM_test_acc.npy', allow_pickle=True)

train_loss_lm_ = np.load('./loss_acc_timing/mnist_cnn_LM_train_loss_.npy', allow_pickle=True)
train_acc_lm_ = np.load('./loss_acc_timing/mnist_cnn_LM_train_acc_.npy', allow_pickle=True)
test_loss_lm_ = np.load('./loss_acc_timing/mnist_cnn_LM_test_loss_.npy', allow_pickle=True) 
test_acc_lm_ = np.load('./loss_acc_timing/mnist_cnn_LM_test_acc_.npy', allow_pickle=True)

train_loss_ekfac_adam = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_train_loss_.npy',allow_pickle=True)
train_acc_ekfac_adam = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_train_acc_.npy',allow_pickle=True)
test_loss_ekfac_adam = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_test_loss_.npy',allow_pickle=True)
test_acc_ekfac_adam = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_test_acc_.npy',allow_pickle=True)

train_loss_ekfac = np.load('./loss_acc_timing/mnist_cnn_EKFAC_train_loss.npy',allow_pickle=True)
train_acc_ekfac = np.load('./loss_acc_timing/mnist_cnn_EKFAC_train_acc.npy',allow_pickle=True)
test_loss_ekfac = np.load('./loss_acc_timing/mnist_cnn_EKFAC_test_loss.npy',allow_pickle=True)
test_acc_ekfac = np.load('./loss_acc_timing/mnist_cnn_EKFAC_test_acc.npy',allow_pickle=True)

train_loss_lbfgs = np.load('./loss_acc_timing/mnist_cnn_lbfgs_train_loss_.npy',allow_pickle=True)
train_acc_lbfgs = np.load('./loss_acc_timing/mnist_cnn_lbfgs_train_acc_.npy',allow_pickle=True)

test_loss_lbfgs = np.load('./loss_acc_timing/mnist_cnn_lbfgs_test_loss_.npy',allow_pickle=True)
test_acc_lbfgs = np.load('./loss_acc_timing/mnist_cnn_lbfgs_test_acc_.npy',allow_pickle=True)

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 50])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 50])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()

# %%
fig, axs = plt.subplots(2,2, sharex=True, figsize=(14, 10))
axs[0,0].plot(train_loss_sgd, label='SGD')
axs[0,0].plot(train_loss_adam, label='Adam')
# axs[0,0].plot(train_loss_lm, label='LM')
axs[0,0].plot(train_loss_lm_, label='LM_')
axs[0,0].plot(train_loss_ekfac, label='EKFAC')
axs[0,0].plot(train_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,0].plot(train_loss_hf, label='HF')
axs[0,0].plot(train_loss_lbfgs, label='lbfgs')
axs[0,0].set_title('training loss curve')
axs[0,0].legend()

axs[0,1].plot(test_loss_sgd, label='SGD')
axs[0,1].plot(test_loss_adam, label='Adam')
# axs[0,1].plot(test_loss_lm, label='LM')
axs[0,1].plot(test_loss_lm_, label='LM_')
axs[0,1].plot(test_loss_ekfac, label='EKFAC')
axs[0,1].plot(test_loss_ekfac_adam, label='EKFAC-Adam')
axs[0,1].plot(test_loss_lbfgs, label='lbfgs')
axs[0,1].set_title('testing loss curve')
axs[0,1].legend()

axs[1,0].plot(train_acc_sgd, label='SGD')
axs[1,0].plot(train_acc_adam, label='Adam')
# axs[1,0].plot(train_acc_lm, label='LM')
axs[1,0].plot(train_acc_lm_, label='LM_')
axs[1,0].plot(train_acc_ekfac, label='EKFAC')
axs[1,0].plot(train_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,0].plot(train_acc_lbfgs, label='lbfgs')
axs[1,0].set_title('training acc curve')
axs[1,0].set_ylim([0, 1])
axs[1,0].set_xlim([0, 17.5])
axs[1,0].set_xlabel('iter')
axs[1,0].legend()


axs[1,1].plot(test_acc_sgd, label='SGD')
axs[1,1].plot(test_acc_adam, label='Adam')
# axs[1,1].plot(test_acc_lm, label='LM')
axs[1,1].plot(test_acc_lm_, label='LM_')
axs[1,1].plot(test_acc_hf, label='HF')
axs[1,1].plot(test_acc_ekfac, label='EKFAC')
axs[1,1].plot(test_acc_ekfac_adam, label='EKFAC-Adam')
axs[1,1].plot(test_acc_lbfgs, label='lbfgs')
axs[1,1].set_title('testing acc curve')
axs[1,1].set_ylim([0, 1])
axs[1,1].set_xlim([0, 17.5])
axs[1,1].set_xlabel('iter')
axs[1,1].legend()
