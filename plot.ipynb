# %% [markdown]
# ### CNN MNIST(10000 train samples)

# %%
import numpy as np
import matplotlib.pyplot as plt
lm_train_loss = np.load('./loss_acc_timing/mnist_cnn_LM_train_loss_.npy', allow_pickle=True)
lm_train_acc = np.load('./loss_acc_timing/mnist_cnn_LM_train_acc_.npy', allow_pickle=True)
lm_test_loss = np.load('./loss_acc_timing/mnist_cnn_LM_test_loss_.npy', allow_pickle=True)
lm_test_acc = np.load('./loss_acc_timing/mnist_cnn_LM_test_acc_.npy', allow_pickle=True)

adam_train_loss = np.load('./loss_acc_timing/mnist_cnn_Adam_train_loss_.npy', allow_pickle=True)
adam_train_acc = np.load('./loss_acc_timing/mnist_cnn_Adam_train_acc_.npy', allow_pickle=True)
adam_test_loss = np.load('./loss_acc_timing/mnist_cnn_Adam_test_loss_.npy', allow_pickle=True)
adam_test_acc = np.load('./loss_acc_timing/mnist_cnn_Adam_test_acc_.npy', allow_pickle=True)

sgd_train_loss = np.load('./loss_acc_timing/mnist_cnn_SGD_train_loss_.npy', allow_pickle=True)
sgd_train_acc = np.load('./loss_acc_timing/mnist_cnn_SGD_train_acc_.npy', allow_pickle=True)
sgd_test_loss = np.load('./loss_acc_timing/mnist_cnn_SGD_test_loss_.npy', allow_pickle=True)
sgd_test_acc = np.load('./loss_acc_timing/mnist_cnn_SGD_test_acc_.npy', allow_pickle=True)

lbfgs_train_loss = np.load('./loss_acc_timing/mnist_cnn_lbfgs_train_loss_.npy', allow_pickle=True)
lbfgs_train_acc = np.load('./loss_acc_timing/mnist_cnn_lbfgs_train_acc_.npy', allow_pickle=True)
lbfgs_test_loss = np.load('./loss_acc_timing/mnist_cnn_lbfgs_test_loss_.npy', allow_pickle=True)
lbfgs_test_acc = np.load('./loss_acc_timing/mnist_cnn_lbfgs_test_acc_.npy', allow_pickle=True)

hf_train_loss = np.load('./loss_acc_timing/mnist_cnn_HF_train_loss_.npy', allow_pickle=True)
hf_train_acc = np.load('./loss_acc_timing/mnist_cnn_HF_train_acc_.npy', allow_pickle=True)
hf_test_loss = np.load('./loss_acc_timing/mnist_cnn_HF_test_loss_.npy', allow_pickle=True)
hf_test_acc = np.load('./loss_acc_timing/mnist_cnn_HF_test_acc_.npy', allow_pickle=True)

ekfac_train_loss = np.load('./loss_acc_timing/mnist_cnn_EKFAC_train_loss_.npy', allow_pickle=True)
ekfac_train_acc = np.load('./loss_acc_timing/mnist_cnn_EKFAC_train_acc_.npy', allow_pickle=True)
ekfac_test_loss = np.load('./loss_acc_timing/mnist_cnn_EKFAC_test_loss_.npy', allow_pickle=True)
ekfac_test_acc = np.load('./loss_acc_timing/mnist_cnn_EKFAC_test_acc_.npy', allow_pickle=True)

ekfac_adam_train_loss = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_train_loss_.npy', allow_pickle=True)
ekfac_adam_train_acc = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_train_acc_.npy', allow_pickle=True)
ekfac_adam_test_loss = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_test_loss_.npy', allow_pickle=True)
ekfac_adam_test_acc = np.load('./loss_acc_timing/mnist_cnn_EKFAC-Adam_test_acc_.npy', allow_pickle=True)



f, axes = plt.subplots(2,2,figsize=(12, 8))
axes[0,0].plot(lm_train_loss, label='LM')
axes[0,0].plot(adam_train_loss, label='Adam')
axes[0,0].plot(sgd_train_loss, label='SGD')
axes[0,0].plot(hf_train_loss, label='HF')
axes[0,0].plot(ekfac_train_loss, label='EKFAC')
axes[0,0].plot(ekfac_adam_train_loss, label='EKFAC-Adam')
axes[0,0].plot(lbfgs_train_loss, label='lbfgs')
axes[0,0].set_title('training loss')
axes[0,0].legend()

axes[0,1].plot(lm_test_loss, label='LM')
axes[0,1].plot(adam_test_loss, label='Adam')
axes[0,1].plot(sgd_test_loss, label='SGD')
axes[0,1].plot(hf_test_loss, label='HF')
axes[0,1].plot(ekfac_test_loss, label='EKFAC')
axes[0,1].plot(ekfac_adam_test_loss, label='EKFAC-Adam')
axes[0,1].plot(lbfgs_test_loss, label='lbfgs')
axes[0,1].set_title('testing loss')
axes[0,1].legend()

axes[1,0].plot(lm_train_acc, label='LM')
axes[1,0].plot(adam_train_acc, label='Adam')
axes[1,0].plot(sgd_train_acc, label='SGD')
axes[1,0].plot(hf_train_acc, label='HF')
axes[1,0].plot(ekfac_train_acc, label='EKFAC')
axes[1,0].plot(ekfac_adam_train_acc, label='EKFAC-Adam')
axes[1,0].plot(lbfgs_train_acc, label='lbfgs')
axes[1,0].set_title('training acc')
axes[1,0].legend()

axes[1,1].plot(lm_test_acc, label='LM')
axes[1,1].plot(adam_test_acc, label='Adam')
axes[1,1].plot(sgd_test_acc, label='SGD')
axes[1,1].plot(hf_test_acc, label='HF')
axes[1,1].plot(ekfac_test_acc, label='EKFAC')
axes[1,1].plot(ekfac_adam_test_acc, label='EKFAC-Adam')
axes[1,1].plot(lbfgs_test_acc, label='lbfgs')
axes[1,1].set_title('testing acc')
axes[1,1].legend()

# %%
sgd_train_acc
# Out:
# array([], dtype=float64)
